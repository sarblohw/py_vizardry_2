# %% [markdown]
# # PAIR Plot

# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
sns.pairplot(tips);

# %%
sns.pairplot(data=tips, kind='reg', diag_kind='kde');

# %%
#note that the tick labels correspond to the relationship plots and not distribution plots
#scatter/reg plots on off diagonals
#histogram/kde on the diagonals
