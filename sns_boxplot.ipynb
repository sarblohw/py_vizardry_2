# %% [markdown]
# # BOX Plot
# - Box and whiskers plot
# - Steps to making a box and whisker plot
#   - Take a variable and plot it on the x/y axis (horizontal/vertical plots)
#   - Find Median
#   - Find the 25th and 75th percentile
#   - Connect the top three to form the box (length = IQR)
#   - Whiskers are marked by default at the last value that lives in the 1.5IQR distance from each side of the box
#   - Points outside whiskers are outliers
# - Catrgorical DIstribution Plot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars = sns.load_dataset('mpg')

# %%
cars.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite

# %%
sns.set_style('whitegrid')

# %%
cars.cylinders.value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
cars = cars.loc[cars['cylinders'].isin([4,6,8])]

# %%
sns.boxplot(data=cars, x='mpg');

# %%
sns.boxenplot(data=cars, x='mpg');
#also study boxenplot

# %%
sns.boxplot(cars.mpg);
# Out:
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
cars.mpg.describe()
# Out:
# count    391.000000
# mean      23.515345
# std        7.847549
# min        9.000000
# 25%       17.000000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
sns.boxplot(data=cars, x='mpg', y='origin');

# %%
sns.boxplot(data=cars, x='origin', y='mpg');

# %%
sns.boxplot(data=cars, x='origin', y='mpg', hue='cylinders');

# %%
cars\
    .model_year\
    .describe()
# Out:
# count    391.000000
# mean      75.992327
# std        3.706189
# min       70.000000
# 25%       73.000000
# 50%       76.000000
# 75%       79.000000
# max       82.000000
# Name: model_year, dtype: float64

# %%
cars['newer_model'] = cars.model_year > 76

# %%
cars.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name  newer_model
# 0          70    usa  chevrolet chevelle malibu        False
# 1          70    usa          buick skylark 320        False
# 2          70    usa         plymouth satellite        False

# %%
sns.boxplot(data=cars, x='origin', y='mpg', hue='newer_model');

# %%
sns.boxplot(data=cars, x='origin', y='mpg');

# %%
sns.boxplot(data=cars, y='origin', x='mpg');

# %%
sns.boxplot(data=cars, x='origin', y='mpg', order=['japan', 'europe', 'usa']);

# %%
sns.boxplot(data=cars, x='origin', y='mpg', hue='newer_model', order=['japan', 'europe', 'usa'], hue_order=[True, False]);

# %%
sns.boxplot(data=cars, x='origin', y='mpg', color='g');

# %%
sns.boxplot(data=cars, x='origin', y='mpg', hue='newer_model', color='g');

# %%
sns.boxplot(data=cars, x='origin', y='mpg', width=0.5);

# %%
sns.boxplot(data=cars, x='origin', y='mpg', width=0.5, linewidth=2.5);

# %%
sns.boxplot(data=cars, x='origin', y='mpg', width=0.5, linewidth=2.5, whis=1);
#whis 1 stands for 1 times IQR as the whisker length

# %%
sns.boxplot(data=cars, x='origin', y='mpg', fliersize=2.5);

# %%
sns.boxplot(data=cars, x='origin', y='mpg', showcaps=False);
